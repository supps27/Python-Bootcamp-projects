# %% [markdown]
# <a href="https://colab.research.google.com/github/supps27/Python-Bootcamp-projects/blob/main/Day_15_Virtual_coffee_machine_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# menu={
#     "espresso":{
#         "Ingridents":{
#             "water":50,
#             "coffee":18,
#         },
#         "cost":1.5
#     },
#     "latte":{
#         "Ingridents":{
#             "water":200,
#             "milk":150,
#             "coffee":24,
#         },
#         "cost":2.5
#     },
#     "cappuccino":{
#         "Ingridents":{
#             "water":250,
#             "milk":100,
#             "coffee":24,
#         },
#         "cost":3.0
#     }
# }

# resources={
#     "water":300,
#     "milk":200,
#     "coffee":100
# }

# print("What would you like?\n")
# count=0
# for items in menu:
#         count+=1
#         print(f"For {items} press {count}")




# def user_choice():
#     """
#     This takes user input of the choice of
#     coffee they want to have and the coins they inserted
#     """

#     your_choice=input('Press for you desired coffee')
#     return your_choice

# user_choice()

# def resources():
#     """
#     This has dict of resources and keeping it
#     inside funcution will help it in reuseblity
#     """
#     stock={
#         "water":100,
#         "Milk":50,
#         "Coffee":76,
#         "Money":2.5,
#     }
#     return stock

# def Make_coffee():
#     """
#     This funcution will process cofee making logic
#     """
#     if user_choice()==1:
#        ingredent=menu['cappuccino']["Ingridents"]
#        return ingredent
#     elif user_choice()==2:
#         ingredent=menu['espresso']['Ingidents']
#         return ingredent
#     elif user_choice()==3:
#         ingredent=menu['latte']['Ingridents']
#     else:
#         print("Item is not there in menu")

#     #resource management
#     for item,amount in ingredent:
#         """using key and value pair"""
#         resources()[item]-=amount

#     print(f"Here is your {user_choice} ")
#     print("Updated resources:", resources )


# Make_coffee()
# Out:
# What would you like?
#
# For espresso press 1
# For latte press 2
# For cappuccino press 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1022980978.py in <cell line: 0>()
#      49     return your_choice
#      50
# ---> 51 user_choice()
#      52
#      53 def resources():
#
# /tmp/ipython-input-1022980978.py in user_choice()
#      46     """
#      47
# ---> 48     your_choice=input('Press for you desired coffee')
#      49     return your_choice
#      50
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
menu={
    "espresso":{
        "Ingridents":{
            "water":50,
            "coffee":18,
        },
        "cost":1.5
    },
    "latte":{
        "Ingridents":{
            "water":200,
            "milk":150,
            "coffee":24,
        },
        "cost":2.5
    },
    "cappuccino":{
        "Ingridents":{
            "water":250,
            "milk":100,
            "coffee":24,
        },
        "cost":3.0
    }
}

# resources={
#     "water":300,
#     "milk":200,
#     "coffee":100
# }


accepted_coin={"quater":0.25,"dimes":0.10,"nickles":0.05,"penneis":0.01}

print("What would you like?\n")
count=0
for items in menu:
        count+=1
        print(f"For {items} press {count}")




def user_choice():
    """
    This takes user input of the choice of
    coffee they want to have and the coins they inserted
    """

    your_choice=int(input('Press for you desired coffee'))
    return your_choice



choice_v=user_choice()



def resources():
    """
    This has dict of resources and keeping it
    inside funcution will help it in reuseblity
    """
    stock={
        "water":300,
        "milk":200,
        "coffee":100,

    }
    return stock
avalavle=resources()

while True:

    def Make_coffee(choice):
        """
        This funcution will process cofee making logic
        """
        coffee_name=''

        # Get coffee name directly from menu keys
        coffee_list = list(menu.keys())

        if 1 <= choice <= len(coffee_list):
            coffee_name = coffee_list[choice - 1]  # maps choice to correct coffee
            ingredent = menu[coffee_name]["Ingridents"]

        elif choice=='report':
            print(avalavle)
            return # Exit the function after reporting

        else:
            print("Item is not there in menu")
            return None






        #resource management



        # Check resources before making
        for item, amount in ingredent.items():
            if avalavle[item] < amount:
                print(f"Sorry, not enough {item}!")
                return  # stop if anything is insufficient

        def process_coin():
            inserted_coin={}
            print(f'cost of {coffee_name} is {menu[coffee_name]["cost"]}')
            for coin_i in accepted_coin:
                print(f"Insert the number of {coin_i} you wanna insert")
                numb=int(input())
                inserted_coin[coin_i]=numb

            coin_val=0
            for coin_g in accepted_coin:

                coin_val+= inserted_coin[coin_g]*accepted_coin[coin_g]

            mrp=menu[coffee_name]['cost']
            if mrp>coin_val:
                print("Insifficent balance")
                return False # Indicate insufficient balance
            else:
                change = coin_val - mrp
                print(f"Here is your change: ${change:.2f}")
                return True # Indicate sufficient balance

        if process_coin(): # Only proceed if enough money was inserted


            for item,amount in ingredent.items(): #this will help to unpack original dict ingredent item with key and value pair
                """using key and value pair"""
                avalavle[item]-=amount


            print(f"Here is your {list(menu.keys())[choice_v-1]} ") #this creates list of keys of menu and [choice-1]access it with indexing
            print("Updated resources:", avalavle ) # Use avalavle instead of resources
            return ingredent # Return the ingredients used


    result = Make_coffee(choice_v) # Assign the result to a variable
    # You can add a condition here to break out of the loop if needed,
    # for example, if Make_coffee returns None or a specific value.
    # if result is None:
    #     break
# Out:
# What would you like?
#
# For espresso press 1
# For latte press 2
# For cappuccino press 3
# Press for you desired coffee1
# cost of espresso is 1.5
# Insert the number of quater you wanna insert
# 5
# Insert the number of dimes you wanna insert
# 0
# Insert the number of nickles you wanna insert
# 10
# Insert the number of penneis you wanna insert
# 0
# Here is your change: $0.25
# Here is your espresso
# Updated resources: {'water': 250, 'milk': 200, 'coffee': 82}
# cost of espresso is 1.5
# Insert the number of quater you wanna insert
# 0
# Insert the number of dimes you wanna insert
# 0
# Insert the number of nickles you wanna insert
# 0
# Insert the number of penneis you wanna insert
# 0
# Insifficent balance
# cost of espresso is 1.5
# Insert the number of quater you wanna insert
# 20
# Insert the number of dimes you wanna insert
# 0
# Insert the number of nickles you wanna insert
# 0
# Insert the number of penneis you wanna insert
# 0
# Here is your change: $3.50
# Here is your espresso
# Updated resources: {'water': 200, 'milk': 200, 'coffee': 64}
# cost of espresso is 1.5
# Insert the number of quater you wanna insert
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-888222545.py", line 147, in <cell line: 0>
#     result = Make_coffee(choice_v) # Assign the result to a variable
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-888222545.py", line 134, in Make_coffee
#     if process_coin(): # Only proceed if enough money was inserted
#        ^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-888222545.py", line 117, in process_coin
#     numb=int(input())
#              ^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 1177, in raw_input
#     return self._input_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 1219, in _input_request
#     raise KeyboardInterrupt("Interrupted by user") from None
# KeyboardInterrupt: Interrupted by user
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1684, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 948, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 988, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#        ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 283, in ismodule
#     def ismodule(object):
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-888222545.py in <cell line: 0>()
#     146
# --> 147     result = Make_coffee(choice_v) # Assign the result to a variable
#     148     # You can add a condition here to break out of the loop if needed,
#
# /tmp/ipython-input-888222545.py in Make_coffee(choice)
#     133
# --> 134         if process_coin(): # Only proceed if enough money was inserted
#     135
#
# /tmp/ipython-input-888222545.py in process_coin()
#     116                 print(f"Insert the number of {coin_i} you wanna insert")
# --> 117                 numb=int(input())
#     118                 inserted_coin[coin_i]=numb
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#
# KeyboardInterrupt: Interrupted by user
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2098                         # in the engines. This should return a list of strings.
# -> 2099                         stb = value._render_traceback_()
#    2100                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2099                         stb = value._render_traceback_()
#    2100                     except Exception:
# -> 2101                         stb = self.InteractiveTB.structured_traceback(etype,
#    2102                                             value, tb, tb_offset=tb_offset)
#    2103
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
